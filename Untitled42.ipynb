# %% [markdown]
# <a href="https://colab.research.google.com/github/poojaanbu0/Ex-1-NN/blob/main/Untitled42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Register Number: 212222240072
##Name: Pooja A

# %%
import pandas as pd                                                 # Importing Libraries
import io
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("Churn_Modelling.csv",index_col="RowNumber")         # Read the dataset from drive

# %%
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
df.isnull().sum()                                                   # Finding Missing Values
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.duplicated().sum()                                               # Check For Duplicates
# Out:
# 0

# %%
df=df.drop(['Surname', 'Geography','Gender'], axis=1)               # Remove Unnecessary Columns

# %%
scaler=StandardScaler()                                             # Normalize the dataset

# %%
df=pd.DataFrame(scaler.fit_transform(df))

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.783213 -0.326221  0.293517 -1.041760 -1.225848 -0.911583  0.646092
# 1 -0.606534 -0.440036  0.198164 -1.387538  0.117350 -0.911583 -1.547768
# 2 -0.995885 -1.536794  0.293517  1.032908  1.333053  2.527057  0.646092
# 3  0.144767  0.501521  0.007457 -1.387538 -1.225848  0.807737 -1.547768
# 4  0.652659  2.063884  0.388871 -1.041760  0.785728 -0.911583  0.646092
#
#           7         8         9
# 0  0.970243  0.021886  1.977165
# 1  0.970243  0.216534 -0.505775
# 2 -1.030670  0.240687  1.977165
# 3 -1.030670 -0.108918 -0.505775
# 4  0.970243 -0.365276 -0.505775

# %%
X,Y=df.iloc[:,:-1].values ,df.iloc[:,-1].values                     # Split the dataset into input and output
print('Input:\n',X,'\nOutput:\n',Y)
# Out:
# Input:
#  [[-0.78321342 -0.32622142  0.29351742 ...  0.64609167  0.97024255
#    0.02188649]
#  [-0.60653412 -0.44003595  0.19816383 ... -1.54776799  0.97024255
#    0.21653375]
#  [-0.99588476 -1.53679418  0.29351742 ...  0.64609167 -1.03067011
#    0.2406869 ]
#  ...
#  [-1.47928179  0.60498839 -0.27860412 ... -1.54776799  0.97024255
#   -1.00864308]
#  [-0.11935577  1.25683526  0.29351742 ...  0.64609167 -1.03067011
#   -0.12523071]
#  [-0.87055909  1.46377078 -1.04143285 ...  0.64609167 -1.03067011
#   -1.07636976]]
# Output:
#  [ 1.97716468 -0.50577476  1.97716468 ...  1.97716468  1.97716468
#  -0.50577476]

# %%
Xtrain,Xtest,Ytrain,Ytest = train_test_split(X, Y, test_size=0.2)   # Splitting the data for training & Testing
print("Xtrain:\n" ,Xtrain, "\nXtest:\n", Xtest)                     # X Train and Test
print("\nYtrain:\n" ,Ytrain, "\nYtest:\n", Ytest)                   # Y Train and Test
# Out:
# Xtrain:
#  [[-0.29057163 -1.46436675 -1.32749362 ...  0.64609167 -1.03067011
#    0.11877262]
#  [ 0.92915369 -0.15032623 -0.37395771 ...  0.64609167  0.97024255
#   -1.33827106]
#  [-0.8210266   0.3877061   0.5795782  ... -1.54776799 -1.03067011
#    0.51785644]
#  ...
#  [-0.36350102  1.0705933   1.05634615 ... -1.54776799  0.97024255
#    0.87980136]
#  [-0.90224153  1.47411755  2.29594283 ... -1.54776799  0.97024255
#   -1.26806662]
#  [-0.17469925  0.16007704  1.91452846 ...  0.64609167  0.97024255
#    1.4786363 ]]
# Xtest:
#  [[-0.1137672   0.86365778 -0.85072567 ...  0.64609167 -1.03067011
#    0.13128713]
#  [-0.77912626 -1.34020544  0.00745665 ... -1.54776799  0.97024255
#   -1.26444275]
#  [-0.10097745  1.22579493  0.00745665 ...  0.64609167  0.97024255
#   -0.91061763]
#  ...
#  [-0.61762784  1.57758531  0.29351742 ...  0.64609167 -1.03067011
#    1.6758926 ]
#  [-0.43066112 -0.13997946  2.00988206 ...  0.64609167  0.97024255
#   -0.520213  ]
#  [ 0.18965577  0.0048754   1.62846769 ...  0.64609167 -1.03067011
#    0.25096571]]
#
# Ytrain:
#  [-0.50577476 -0.50577476 -0.50577476 ... -0.50577476 -0.50577476
#  -0.50577476]
# Ytest:
#  [-0.50577476 -0.50577476 -0.50577476 ...  1.97716468 -0.50577476
#   1.97716468]
